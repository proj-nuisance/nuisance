# %%
from nuisancelib import *
# %matplotlib inline

# %% [markdown]
# ### FUNCTIONS YOU CAN USE:
#
# `analyses(filepath)` spits out a nifty heatmap to let you check correlation between variables
#
# `regress(option, df)` churns out a saucy graph of the linear regression for the variables you provided, where
#        option is 'snr_total' or 'tsnr', whichever you want to make the dependent variable of your model
#        df is the pandas DataFrame containing your data. To modify which variables you want in your model, you'll
#              have to directly modify the regress function

# %% [markdown]
# ### NOTABLE FILENAMES
#  - `../data/extractions/anat.csv` - all possible dates for anatomical data

# %% [markdown]
# #   Analyses

# %%
analyses('../data/extractions/anat.csv')
# Out:
# All Conversion Softwares are the same: True

# %% [markdown]
# # Model Creation

# %%
df3 = pd.read_csv('../data/extractions/anat.csv', parse_dates=['Date'])
df3
# Out:
#          Date             Filetype  snr_total       SAR  AcquisitionTime  \
# 0  2017-10-30  acq-MPRAGE_T1w.json  45.609948  0.033092            39009
# 1  2017-11-06  acq-MPRAGE_T1w.json  49.575077  0.033160            41814
# 2  2017-11-13  acq-MPRAGE_T1w.json  47.308825  0.033247            37638
# 3  2017-11-20  acq-MPRAGE_T1w.json  53.461779  0.033159            36473
# 4  2017-11-27  acq-MPRAGE_T1w.json  48.981048  0.033078            37165
# 5  2017-12-04  acq-MPRAGE_T1w.json  56.570965  0.033255            41697
# 6  2017-12-18  acq-MPRAGE_T1w.json  46.212688  0.033263            35022
# 7  2018-01-02  acq-MPRAGE_T1w.json  54.843520  0.033227            42512
# 8  2018-01-08  acq-MPRAGE_T1w.json  51.152603  0.028424            34889
# 9  2018-01-15  acq-MPRAGE_T1w.json  56.041984  0.039198            36327
# 10 2018-01-22  acq-MPRAGE_T1w.json  52.976081  0.033313            54287
# 11 2018-01-29  acq-MPRAGE_T1w.json  48.414564  0.033188            37194
# 12 2018-02-05  acq-MPRAGE_T1w.json  50.733794  0.039186            37607
# 13 2018-02-12  acq-MPRAGE_T1w.json  47.230603  0.028386            33660
# 14 2018-02-19  acq-MPRAGE_T1w.json  50.208423  0.033141            35612
# 15 2018-02-26  acq-MPRAGE_T1w.json  49.593884  0.033244            33390
# 16 2018-03-05  acq-MPRAGE_T1w.json  48.234458  0.033191            35167
# 17 2018-03-12  acq-MPRAGE_T1w.json  51.224813  0.033228            34890
# 18 2018-03-19  acq-MPRAGE_T1w.json  50.998323  0.033278            35903
# 19 2018-03-26  acq-MPRAGE_T1w.json  48.910974  0.033194            34980
# 20 2018-04-05  acq-MPRAGE_T1w.json  53.306891  0.033205            37667
# 21 2018-04-09  acq-MPRAGE_T1w.json  44.379597  0.033212            32961
# 22 2018-04-16  acq-MPRAGE_T1w.json  49.782443  0.033304            36349
# 23 2018-04-23  acq-MPRAGE_T1w.json  48.014166  0.033146            36273
# 24 2018-04-26  acq-MPRAGE_T1w.json  47.273131  0.028408            34203
# 25 2018-04-30  acq-MPRAGE_T1w.json  48.445186  0.033141            33076
# 26 2018-05-07  acq-MPRAGE_T1w.json  49.062765  0.033143            38793
# 27 2018-05-14  acq-MPRAGE_T1w.json  48.504801  0.033083            33410
# 28 2018-05-29  acq-MPRAGE_T1w.json  50.397586  0.028448            59495
# 29 2018-05-31  acq-MPRAGE_T1w.json  50.911788  0.033087            32951
# 30 2018-06-04  acq-MPRAGE_T1w.json  51.176543  0.032982            49427
# 31 2018-06-11  acq-MPRAGE_T1w.json  49.560839  0.033077            39481
# 32 2018-06-18  acq-MPRAGE_T1w.json  49.127320  0.033129            36105
# 33 2018-06-25  acq-MPRAGE_T1w.json  50.351892  0.033031            41604
# 34 2018-07-02  acq-MPRAGE_T1w.json  51.194094  0.033234            39708
# 35 2018-07-09  acq-MPRAGE_T1w.json  47.679879  0.033097            36599
# 36 2018-07-23  acq-MPRAGE_T1w.json  53.042607  0.033135            33725
# 37 2018-07-30  acq-MPRAGE_T1w.json  52.508069  0.033033            48832
# 38 2018-08-09  acq-MPRAGE_T1w.json  51.073192  0.033139            46568
# 39 2018-08-13  acq-MPRAGE_T1w.json  48.412473  0.033055            34864
# 40 2018-08-20  acq-MPRAGE_T1w.json  51.739376  0.033162            47134
# 41 2018-08-27  acq-MPRAGE_T1w.json  46.076735  0.028354            41955
# 42 2018-09-04  acq-MPRAGE_T1w.json  47.538107  0.033077            36129
# 43 2018-09-10  acq-MPRAGE_T1w.json  48.585167  0.033045            47501
#
#     TxRefAmp SoftwareVersions                                      CSV  \
# 0    230.573     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 1    231.487     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 2    231.326     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 3    229.930     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 4    227.070     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 5    231.932     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 6    227.181     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 7    227.526     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 8    231.071     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 9    226.420     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 10   233.036     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 11   235.564     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 12   231.349     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 13   230.705     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 14   229.376     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 15   232.820     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 16   229.223     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 17   232.269     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 18   227.849     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 19   230.030     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 20   231.664     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 21   229.727     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 22   232.243     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 23   230.270     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 24   231.226     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 25   232.198     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 26   233.584     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 27   237.643     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 28   237.711     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 29   235.255     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 30   233.526     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 31   235.423     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 32   236.930     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 33   234.779     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 34   235.951     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 35   234.563     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 36   234.672     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 37   236.183     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 38   235.417     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 39   235.016     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 40   235.455     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 41   238.067     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 42   233.861     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 43   234.145     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
#
#     RepetitionTime  Shim1  ...  Shim5  Shim6  Shim7  Shim8     IOPD1  \
# 0              2.3   4146  ...    -55    -88    -63     64  0.976457
# 1              2.3   4146  ...    -55    -88    -63     64 -0.008877
# 2              2.3   4146  ...    -55    -88    -63     64 -0.149058
# 3              2.3   4146  ...    -55    -88    -63     64 -0.148262
# 4              2.3   4146  ...    -55    -88    -63     64 -0.159926
# 5              2.3   4146  ...    -55    -88    -63     64 -0.007184
# 6              2.3   4146  ...    -55    -88    -63     64 -0.178403
# 7              2.3   4146  ...    -55    -88    -63     64 -0.005452
# 8              2.3   4146  ...    -55    -88    -63     64 -0.146475
# 9              2.3   4146  ...    -55    -88    -63     64  0.137367
# 10             2.3   4146  ...    -55    -88    -63     64 -0.150067
# 11             2.3   4146  ...    -55    -88    -63     64  0.156184
# 12             2.3   4146  ...    -55    -88    -63     64  0.138340
# 13             2.3   4146  ...    -55    -88    -63     64 -0.159486
# 14             2.3   4146  ...    -55    -88    -63     64 -0.160957
# 15             2.3   4146  ...    -55    -88    -63     64 -0.200869
# 16             2.3   4146  ...    -55    -88    -63     64 -0.180274
# 17             2.3   4146  ...    -55    -88    -63     64 -0.168463
# 18             2.3   4146  ...    -55    -88    -63     64  0.170401
# 19             2.3   4146  ...    -55    -88    -63     64 -0.195285
# 20             2.3   4146  ...    -55    -88    -63     64 -0.010319
# 21             2.3   4146  ...    -55    -88    -63     64  0.039958
# 22             2.3   4146  ...    -55    -88    -63     64  0.167408
# 23             2.3   4146  ...    -55    -88    -63     64 -0.186873
# 24             2.3   4146  ...    -55    -88    -63     64 -0.167562
# 25             2.3   4146  ...    -55    -88    -63     64 -0.169028
# 26             2.3   4146  ...    -55    -88    -63     64  0.100726
# 27             2.3   4146  ...    -55    -88    -63     64 -0.147892
# 28             2.3   4146  ...    -55    -88    -63     64 -0.214959
# 29             2.3   4146  ...    -55    -88    -63     64 -0.157266
# 30             2.3   4146  ...    -55    -88    -63     64  0.068743
# 31             2.3   4146  ...    -55    -88    -63     64 -0.147437
# 32             2.3   4146  ...    -55    -88    -63     64  0.186292
# 33             2.3   4146  ...    -55    -88    -63     64  0.156515
# 34             2.3   4146  ...    -55    -88    -63     64  0.116411
# 35             2.3   4146  ...    -55    -88    -63     64  0.157732
# 36             2.3   4146  ...    -55    -88    -63     64 -0.176475
# 37             2.3   4146  ...    -55    -88    -63     64 -0.156970
# 38             2.3   4146  ...    -55    -88    -63     64 -0.168290
# 39             2.3   4146  ...    -55    -88    -63     64  0.179523
# 40             2.3   4146  ...    -55    -88    -63     64 -0.206178
# 41             2.3   4146  ...    -55    -88    -63     64 -0.209734
# 42             2.3   4146  ...    -55    -88    -63     64  0.129479
# 43             2.3   4146  ...    -55    -88    -63     64 -0.205823
#
#        IOPD2     IOPD3     IOPD4     IOPD5     IOPD6
# 0   0.215037  0.017022 -0.214688  0.961130  0.173603
# 1   0.953414  0.301535  0.001560  0.301560 -0.953446
# 2   0.939970  0.306983 -0.065152  0.300441 -0.951573
# 3   0.938058  0.313154 -0.040535  0.310623 -0.949669
# 4   0.939737  0.302187 -0.040033  0.299701 -0.953193
# 5   0.956126  0.292867  0.003875  0.292899 -0.956135
# 6   0.937474  0.298855 -0.044262  0.295774 -0.954232
# 7   0.957707  0.287694  0.001296  0.287705 -0.957718
# 8   0.942721  0.299703 -0.040477  0.297005 -0.954018
# 9   0.941411  0.308019  0.048340  0.304225 -0.951373
# 10  0.939745  0.307179 -0.039278  0.304785 -0.951611
# 11  0.938453  0.308080  0.023287  0.308323 -0.950997
# 12  0.939681  0.312830  0.049838  0.308862 -0.949800
# 13  0.937592  0.309007 -0.043265  0.306074 -0.951024
# 14  0.937887  0.307343 -0.042349  0.304554 -0.951553
# 15  0.931248  0.304020 -0.054740  0.299191 -0.952622
# 16  0.937068  0.299007 -0.040895  0.296584 -0.954131
# 17  0.938568  0.301181 -0.040057  0.298777 -0.953482
# 18  0.938690  0.299707  0.054720  0.294671 -0.954031
# 19  0.935111  0.295687 -0.048115  0.291994 -0.955209
# 20  0.953242  0.302031  0.003665  0.302081 -0.953275
# 21  0.931214  0.362275  0.017222  0.361869 -0.932070
# 22  0.937945  0.303699  0.056327  0.298444 -0.952764
# 23  0.934806  0.302020 -0.048306  0.298320 -0.953243
# 24  0.936950  0.306672 -0.042230  0.303963 -0.951747
# 25  0.936141  0.308333 -0.043095  0.305516 -0.951211
# 26  0.947803  0.302529  0.038989  0.300082 -0.953116
# 27  0.941547  0.302684 -0.035450  0.300806 -0.953026
# 28  0.928370  0.303187 -0.058347  0.297682 -0.952880
# 29  0.943136  0.292852 -0.036083  0.290857 -0.956086
# 30  0.950021  0.304523  0.030160  0.303126 -0.952473
# 31  0.941936  0.301693 -0.037757  0.299444 -0.953366
# 32  0.943882  0.272730  0.032496  0.271518 -0.961885
# 33  0.939286  0.305361  0.053656  0.300629 -0.952231
# 34  0.945949  0.302701  0.040136  0.300044 -0.953081
# 35  0.939728  0.303367  0.052389  0.298817 -0.952871
# 36  0.934323  0.309672 -0.049688  0.305753 -0.950814
# 37  0.936696  0.312988 -0.043516  0.310049 -0.949724
# 38  0.936598  0.307349 -0.047176  0.303786 -0.951572
# 39  0.935215  0.305196  0.059194  0.299405 -0.952288
# 40  0.929543  0.305679 -0.055573  0.300763 -0.952078
# 41  0.929463  0.303498 -0.050965  0.299587 -0.952707
# 42  0.931101  0.341009  0.033693  0.339574 -0.939976
# 43  0.929514  0.306007 -0.054270  0.301379 -0.951959
#
# [44 rows x 23 columns]

# %%
regress('snr_total', df3)
# Out:
# /home/yoh/proj/experiments/nuisance/ipy/nuisancelib.py:131: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   model_df['Date'] = model_df['Date'].map(pd.datetime.toordinal)
# Statistically significant variables: ['IOPD1', 'IOPD2', 'IOPD3', 'IOPD4', 'IOPD5', 'IOPD6', 'const', 'AcquisitionTime', 'SAR']
# FDR-corrected p-values:
# AcquisitionTime | Original  p-value:   0.0188 | FDR-corrected p-value:   0.0313**
#             SAR | Original  p-value:  0.00349 | FDR-corrected p-value:   0.0175**
#        TxRefAmp | Original  p-value:    0.382 | FDR-corrected p-value:    0.477
#            IOPD | Original  p-value:   0.0153 | FDR-corrected p-value:   0.0313**
#        Seasonal | Original  p-value:    0.669 | FDR-corrected p-value:    0.669
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              snr_total   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     3.326
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):            0.00385
# Time:                        09:10:59   Log-Likelihood:                -87.912
# No. Observations:                  44   AIC:                             199.8
# Df Residuals:                      32   BIC:                             221.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              49.9188      0.315    158.253      0.000      49.276      50.561
# AcquisitionTime     0.0001   5.35e-05      2.476      0.019    2.35e-05       0.000
# SAR               492.2450    156.081      3.154      0.003     174.319     810.171
# TxRefAmp           -0.1033      0.116     -0.887      0.382      -0.340       0.134
# IOPD1              -2.8141      1.572     -1.790      0.083      -6.016       0.388
# IOPD2               7.5256      4.485      1.678      0.103      -1.610      16.661
# IOPD3             -67.4875     22.938     -2.942      0.006    -114.210     -20.765
# IOPD4              -8.3575     40.955     -0.204      0.840     -91.780      75.065
# IOPD5              93.1890     46.409      2.008      0.053      -1.342     187.720
# IOPD6             114.7569    289.843      0.396      0.695    -475.634     705.148
# Seasonal (sin)     -0.2147      0.546     -0.393      0.697      -1.326       0.897
# Seasonal (cos)      0.6067      0.746      0.813      0.422      -0.914       2.127
# ==============================================================================
# Omnibus:                        0.926   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.463
# Skew:                           0.245   Prob(JB):                        0.793
# Kurtosis:                       3.114   Cond. No.                     5.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AIC: 199.82491179654644
# BIC: 221.2351874035656

# %%
# might want to do twice to avoid all the warnings display from xlswriter
import pandas as pd, statsmodels as sm, seaborn as sb
pd.show_versions();
print("seaborn:      ", sb.__version__)
print("statsmodels:  ", sm.__version__)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.7.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.6.0-1-amd64
# machine          : x86_64
# processor        :
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.3
# numpy            : 1.18.1
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.0.2
# setuptools       : 47.1.1.post20200604
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.13.0
# pandas_datareader: None
# bs4              : None
# bottleneck       : None
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : None
# matplotlib       : 3.1.3
# numexpr          : None
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# pytest           : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.4.1
# sqlalchemy       : None
# tables           : None
# tabulate         : None
# xarray           : None
# xlrd             : None
# xlwt             : None
# xlsxwriter       : None
# numba            : None
# seaborn:       0.10.1
# statsmodels:   0.11.1
