# %%
from nuisancelib import *
# %matplotlib inline

# %% [markdown]
# ### FUNCTIONS YOU CAN USE:
#
# `analyses(filepath)` spits out a nifty heatmap to let you check correlation between variables
#
# `regress(option, df)` churns out a saucy graph of the linear regression for the variables you provided, where
#        option is 'snr_total' or 'tsnr', whichever you want to make the dependent variable of your model
#        df is the pandas DataFrame containing your data. To modify which variables you want in your model, you'll
#              have to directly modify the regress function

# %% [markdown]
# ### NOTABLE FILENAMES
#  - `../data/extractions/anat.csv` - all possible dates for anatomical data

# %% [markdown]
# #   Analyses

# %%
analyses('../data/extractions/anat.csv')
# Out:
# All Conversion Softwares are the same: False

# %% [markdown]
# # Model Creation

# %%
df3 = pd.read_csv('../data/extractions/anat.csv', parse_dates=['Date'])
df3
# Out:
#          Date  AcquisitionTime       SAR  TxRefAmp     IOPD1     IOPD2  \
# 0  2017-10-30            39009  0.033092   230.573  0.976457  0.215037
# 1  2017-11-06            41814  0.033160   231.487 -0.008877  0.953414
# 2  2017-11-13            37638  0.033247   231.326 -0.149058  0.939970
# 3  2017-11-20            36473  0.033159   229.930 -0.148262  0.938058
# 4  2017-11-27            37165  0.033078   227.070 -0.159926  0.939737
# 5  2017-12-04            41697  0.033255   231.932 -0.007184  0.956126
# 6  2017-12-18            35022  0.033263   227.181 -0.178403  0.937474
# 7  2018-01-02            42512  0.033227   227.526 -0.005452  0.957707
# 8  2018-01-08            34889  0.028424   231.071 -0.146475  0.942721
# 9  2018-01-15            36327  0.039198   226.420  0.137367  0.941411
# 10 2018-01-22            54287  0.033313   233.036 -0.150067  0.939745
# 11 2018-01-29            37194  0.033188   235.564  0.156184  0.938453
# 12 2018-02-05            37607  0.039186   231.349  0.138340  0.939681
# 13 2018-02-12            33660  0.028386   230.705 -0.159486  0.937592
# 14 2018-02-19            35612  0.033141   229.376 -0.160957  0.937887
# 15 2018-02-26            33390  0.033244   232.820 -0.200869  0.931248
# 16 2018-03-05            35167  0.033191   229.223 -0.180274  0.937068
# 17 2018-03-12            34890  0.033228   232.269 -0.168463  0.938568
# 18 2018-03-19            35903  0.033278   227.849  0.170401  0.938690
# 19 2018-03-26            34980  0.033194   230.030 -0.195285  0.935111
# 20 2018-04-05            37667  0.033205   231.664 -0.010319  0.953242
# 21 2018-04-09            32961  0.033212   229.727  0.039958  0.931214
# 22 2018-04-16            36349  0.033304   232.243  0.167408  0.937945
# 23 2018-04-23            36273  0.033146   230.270 -0.186873  0.934806
# 24 2018-04-26            34203  0.028408   231.226 -0.167562  0.936950
# 25 2018-04-30            33076  0.033141   232.198 -0.169028  0.936141
# 26 2018-05-07            38793  0.033143   233.584  0.100726  0.947803
# 27 2018-05-14            33410  0.033083   237.643 -0.147892  0.941547
# 28 2018-05-29            59495  0.028448   237.711 -0.214959  0.928370
# 29 2018-05-31            32951  0.033087   235.255 -0.157266  0.943136
# 30 2018-06-04            49427  0.032982   233.526  0.068743  0.950021
# 31 2018-06-11            39481  0.033077   235.423 -0.147437  0.941936
# 32 2018-06-18            36105  0.033129   236.930  0.186292  0.943882
# 33 2018-06-25            41604  0.033031   234.779  0.156515  0.939286
# 34 2018-07-02            39708  0.033234   235.951  0.116411  0.945949
# 35 2018-07-09            36599  0.033097   234.563  0.157732  0.939728
# 36 2018-07-23            33725  0.033135   234.672 -0.176475  0.934323
# 37 2018-07-30            48832  0.033033   236.183 -0.156970  0.936696
# 38 2018-08-09            46568  0.033139   235.417 -0.168290  0.936598
# 39 2018-08-13            34864  0.033055   235.016  0.179523  0.935215
# 40 2018-08-20            47134  0.033162   235.455 -0.206178  0.929543
# 41 2018-08-27            41955  0.028354   238.067 -0.209734  0.929463
# 42 2018-09-04            36129  0.033077   233.861  0.129479  0.931101
# 43 2018-09-10            47501  0.033045   234.145 -0.205823  0.929514
#
#        IOPD3     IOPD4     IOPD5     IOPD6  snr_total             Filetype  \
# 0   0.017022 -0.214688  0.961130  0.173603  45.609948  acq-MPRAGE_T1w.json
# 1   0.301535  0.001560  0.301560 -0.953446  49.575077  acq-MPRAGE_T1w.json
# 2   0.306983 -0.065152  0.300441 -0.951573  47.308825  acq-MPRAGE_T1w.json
# 3   0.313154 -0.040535  0.310623 -0.949669  53.461779  acq-MPRAGE_T1w.json
# 4   0.302187 -0.040033  0.299701 -0.953193  48.981048  acq-MPRAGE_T1w.json
# 5   0.292867  0.003875  0.292899 -0.956135  56.570965  acq-MPRAGE_T1w.json
# 6   0.298855 -0.044262  0.295774 -0.954232  46.212688  acq-MPRAGE_T1w.json
# 7   0.287694  0.001296  0.287705 -0.957718  54.843520  acq-MPRAGE_T1w.json
# 8   0.299703 -0.040477  0.297005 -0.954018  51.152603  acq-MPRAGE_T1w.json
# 9   0.308019  0.048340  0.304225 -0.951373  56.041984  acq-MPRAGE_T1w.json
# 10  0.307179 -0.039278  0.304785 -0.951611  52.976081  acq-MPRAGE_T1w.json
# 11  0.308080  0.023287  0.308323 -0.950997  48.414564  acq-MPRAGE_T1w.json
# 12  0.312830  0.049838  0.308862 -0.949800  50.733794  acq-MPRAGE_T1w.json
# 13  0.309007 -0.043265  0.306074 -0.951024  47.230603  acq-MPRAGE_T1w.json
# 14  0.307343 -0.042349  0.304554 -0.951553  50.208423  acq-MPRAGE_T1w.json
# 15  0.304020 -0.054740  0.299191 -0.952622  49.593884  acq-MPRAGE_T1w.json
# 16  0.299007 -0.040895  0.296584 -0.954131  48.234458  acq-MPRAGE_T1w.json
# 17  0.301181 -0.040057  0.298777 -0.953482  51.224813  acq-MPRAGE_T1w.json
# 18  0.299707  0.054720  0.294671 -0.954031  50.998323  acq-MPRAGE_T1w.json
# 19  0.295687 -0.048115  0.291994 -0.955209  48.910974  acq-MPRAGE_T1w.json
# 20  0.302031  0.003665  0.302081 -0.953275  53.306891  acq-MPRAGE_T1w.json
# 21  0.362275  0.017222  0.361869 -0.932070  44.379597  acq-MPRAGE_T1w.json
# 22  0.303699  0.056327  0.298444 -0.952764  49.782443  acq-MPRAGE_T1w.json
# 23  0.302020 -0.048306  0.298320 -0.953243  48.014166  acq-MPRAGE_T1w.json
# 24  0.306672 -0.042230  0.303963 -0.951747  47.273131  acq-MPRAGE_T1w.json
# 25  0.308333 -0.043095  0.305516 -0.951211  48.445186  acq-MPRAGE_T1w.json
# 26  0.302529  0.038989  0.300082 -0.953116  49.062765  acq-MPRAGE_T1w.json
# 27  0.302684 -0.035450  0.300806 -0.953026  48.504801  acq-MPRAGE_T1w.json
# 28  0.303187 -0.058347  0.297682 -0.952880  50.397586  acq-MPRAGE_T1w.json
# 29  0.292852 -0.036083  0.290857 -0.956086  50.911788  acq-MPRAGE_T1w.json
# 30  0.304523  0.030160  0.303126 -0.952473  51.176543  acq-MPRAGE_T1w.json
# 31  0.301693 -0.037757  0.299444 -0.953366  49.560839  acq-MPRAGE_T1w.json
# 32  0.272730  0.032496  0.271518 -0.961885  49.127320  acq-MPRAGE_T1w.json
# 33  0.305361  0.053656  0.300629 -0.952231  50.351892  acq-MPRAGE_T1w.json
# 34  0.302701  0.040136  0.300044 -0.953081  51.194094  acq-MPRAGE_T1w.json
# 35  0.303367  0.052389  0.298817 -0.952871  47.679879  acq-MPRAGE_T1w.json
# 36  0.309672 -0.049688  0.305753 -0.950814  53.042607  acq-MPRAGE_T1w.json
# 37  0.312988 -0.043516  0.310049 -0.949724  52.508069  acq-MPRAGE_T1w.json
# 38  0.307349 -0.047176  0.303786 -0.951572  51.073192  acq-MPRAGE_T1w.json
# 39  0.305196  0.059194  0.299405 -0.952288  48.412473  acq-MPRAGE_T1w.json
# 40  0.305679 -0.055573  0.300763 -0.952078  51.739376  acq-MPRAGE_T1w.json
# 41  0.303498 -0.050965  0.299587 -0.952707  46.076735  acq-MPRAGE_T1w.json
# 42  0.341009  0.033693  0.339574 -0.939976  47.538107  acq-MPRAGE_T1w.json
# 43  0.306007 -0.054270  0.301379 -0.951959  48.585167  acq-MPRAGE_T1w.json
#
#    SoftwareVersions                                      CSV
# 0      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 1      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 2      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 3      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 4      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 5      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 6      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 7      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 8      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 9      syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 10     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 11     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 12     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 13     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 14     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 15     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 16     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 17     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 18     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 19     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 20     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 21     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 22     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 23     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 24     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 25     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 26     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 27     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 28     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 29     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 30     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 31     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 32     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 33     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 34     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 35     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 36     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 37     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 38     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 39     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 40     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 41     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 42     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 43     syngo_MR_E11  v1.0.20171215 (OpenJPEG build) GCC6.3.0

# %%
regress('snr_total', df3)
# Out:
# /home/yoh/proj/experiments/nuisance/ipy/nuisancelib.py:131: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   model_df['Date'] = model_df['Date'].map(pd.datetime.toordinal)
# Statistically significant variables: ['IOPD1', 'IOPD2', 'IOPD3', 'IOPD4', 'IOPD5', 'IOPD6', 'const', 'AcquisitionTime', 'SAR']
# FDR-corrected p-values:
# AcquisitionTime | Original  p-value:   0.0188 | FDR-corrected p-value:   0.0313**
#             SAR | Original  p-value:  0.00349 | FDR-corrected p-value:   0.0175**
#        TxRefAmp | Original  p-value:    0.382 | FDR-corrected p-value:    0.477
#            IOPD | Original  p-value:   0.0153 | FDR-corrected p-value:   0.0313**
#        Seasonal | Original  p-value:    0.669 | FDR-corrected p-value:    0.669
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              snr_total   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     3.326
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):            0.00385
# Time:                        09:21:19   Log-Likelihood:                -87.912
# No. Observations:                  44   AIC:                             199.8
# Df Residuals:                      32   BIC:                             221.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              49.9188      0.315    158.253      0.000      49.276      50.561
# AcquisitionTime     0.0001   5.35e-05      2.476      0.019    2.35e-05       0.000
# SAR               492.2450    156.081      3.154      0.003     174.319     810.171
# TxRefAmp           -0.1033      0.116     -0.887      0.382      -0.340       0.134
# IOPD1              -2.8141      1.572     -1.790      0.083      -6.016       0.388
# IOPD2               7.5256      4.485      1.678      0.103      -1.610      16.661
# IOPD3             -67.4875     22.938     -2.942      0.006    -114.210     -20.765
# IOPD4              -8.3575     40.955     -0.204      0.840     -91.780      75.065
# IOPD5              93.1890     46.409      2.008      0.053      -1.342     187.720
# IOPD6             114.7569    289.843      0.396      0.695    -475.634     705.148
# Seasonal (sin)     -0.2147      0.546     -0.393      0.697      -1.326       0.897
# Seasonal (cos)      0.6067      0.746      0.813      0.422      -0.914       2.127
# ==============================================================================
# Omnibus:                        0.926   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.463
# Skew:                           0.245   Prob(JB):                        0.793
# Kurtosis:                       3.114   Cond. No.                     5.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AIC: 199.8249117902646
# BIC: 221.2351873972837

# %%
# might want to do twice to avoid all the warnings display from xlswriter
import pandas as pd, statsmodels as sm, seaborn as sb
pd.show_versions();
print("seaborn:      ", sb.__version__)
print("statsmodels:  ", sm.__version__)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.7.7.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.6.0-1-amd64
# machine          : x86_64
# processor        :
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.3
# numpy            : 1.18.1
# pytz             : 2020.1
# dateutil         : 2.8.1
# pip              : 20.0.2
# setuptools       : 47.1.1.post20200604
# Cython           : None
# pytest           : None
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.2
# IPython          : 7.13.0
# pandas_datareader: None
# bs4              : None
# bottleneck       : None
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : None
# matplotlib       : 3.1.3
# numexpr          : None
# odfpy            : None
# openpyxl         : None
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# pytest           : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.4.1
# sqlalchemy       : None
# tables           : None
# tabulate         : None
# xarray           : None
# xlrd             : None
# xlwt             : None
# xlsxwriter       : None
# numba            : None
# seaborn:       0.10.1
# statsmodels:   0.11.1
