# %%
from nuisancelib import *
# %matplotlib inline

# %%
import pandas as pd, statsmodels as sm
pd.show_versions();
print("Statsmodels:  ", sm.__version__)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : None
# python           : 3.6.4.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 18.6.0
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.0.4
# numpy            : 1.18.4
# pytz             : 2017.3
# dateutil         : 2.6.1
# pip              : 20.1.1
# setuptools       : 38.4.0
# Cython           : 0.27.3
# pytest           : 3.3.2
# hypothesis       : None
# sphinx           : 1.6.6
# blosc            : None
# feather          : None
# xlsxwriter       : 1.0.2
# lxml.etree       : 4.1.1
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.10
# IPython          : 6.2.1
# pandas_datareader: None
# bs4              : 4.5.3
# bottleneck       : 1.2.1
# fastparquet      : None
# gcsfs            : None
# lxml.etree       : 4.1.1
# matplotlib       : 3.2.1
# numexpr          : 2.6.4
# odfpy            : None
# openpyxl         : 2.4.10
# pandas_gbq       : None
# pyarrow          : None
# pytables         : None
# pytest           : 3.3.2
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.1.0
# sqlalchemy       : 1.2.1
# tables           : 3.4.2
# tabulate         : None
# xarray           : 0.14.1
# xlrd             : 1.0.0
# xlwt             : 1.2.0
# xlsxwriter       : 1.0.2
# numba            : 0.36.2
# Statsmodels:   0.9.0

# %%
# FUNCTIONS YOU CAN USE:
#     analyses(filepath) spits out a nifty heatmap to let you check correlation between variables
#
#     regress(option, df) churns out a saucy graph of the linear regression for the variables you provided, where
#       option is 'snr_total' or 'tsnr', whichever you want to make the dependent variable of your model
#       df is the pandas DataFrame containing your data. To modify which variables you want in your model, you'll
#             have to directly modify the regress function

# %%
# NOTABLE FILENAMES
# ../data/extractions/p2_BOLD.csv                  - all dates for p2_BOLD
# ../data/extractions/p2Xs4X35mm_BOLD.csv          - all dates for p2Xs4X35mm_BOLD
# ../data/extractions/anat.csv                     - all possible dates for anatomical data

# %% [markdown]
# #   Analyses

# %%
analyses('../data/extractions/p2_BOLD.csv')
# Out:
# All Conversion Softwares are the same: True

# %%
analyses('../data/extractions/p2_BOLD_snr.csv')
# Out:
# All Conversion Softwares are the same: True

# %%
analyses('../data/extractions/anat.csv')
# Out:
# All Conversion Softwares are the same: False

# %% [markdown]
# # Model Creation

# %%
df = pd.read_csv('../data/extractions/p2_BOLD.csv', parse_dates=['Date'])
df
# Out:
#          Date                    Filetype        tsnr       SAR  \
# 0  2016-11-28  task-rest_acq-p2_bold.json  239.879349  0.055556
# 1  2016-12-05  task-rest_acq-p2_bold.json  245.208572  0.047561
# 2  2016-12-12  task-rest_acq-p2_bold.json  205.039551  0.047769
# 3  2016-12-19  task-rest_acq-p2_bold.json  223.930527  0.055699
# 4  2017-01-03  task-rest_acq-p2_bold.json  180.165283  0.055624
# 5  2017-01-09  task-rest_acq-p2_bold.json  246.492493  0.055723
# 6  2017-01-17  task-rest_acq-p2_bold.json  237.618591  0.055807
# 7  2017-01-23  task-rest_acq-p2_bold.json  190.646790  0.055747
# 8  2017-01-30  task-rest_acq-p2_bold.json  257.484131  0.055683
# 9  2017-02-06  task-rest_acq-p2_bold.json  235.091019  0.055883
# 10 2017-02-13  task-rest_acq-p2_bold.json  259.120178  0.047701
# 11 2017-02-27  task-rest_acq-p2_bold.json  290.682190  0.055656
# 12 2017-03-09  task-rest_acq-p2_bold.json  180.471649  0.047735
# 13 2017-03-13  task-rest_acq-p2_bold.json  216.713287  0.047713
# 14 2017-03-20  task-rest_acq-p2_bold.json  201.686233  0.055635
# 15 2017-03-27  task-rest_acq-p2_bold.json  234.626007  0.055658
# 16 2017-03-29  task-rest_acq-p2_bold.json  298.131775  0.055812
# 17 2017-04-03  task-rest_acq-p2_bold.json  273.925812  0.055705
# 18 2017-04-10  task-rest_acq-p2_bold.json  263.824402  0.055486
# 19 2017-04-17  task-rest_acq-p2_bold.json  280.597260  0.055634
# 20 2017-04-24  task-rest_acq-p2_bold.json  235.977707  0.047588
# 21 2017-05-01  task-rest_acq-p2_bold.json  253.499268  0.055664
# 22 2017-05-08  task-rest_acq-p2_bold.json  235.625320  0.047864
# 23 2017-05-15  task-rest_acq-p2_bold.json  247.676819  0.055718
# 24 2017-05-22  task-rest_acq-p2_bold.json  259.791901  0.055695
# 25 2017-05-30  task-rest_acq-p2_bold.json  264.461914  0.055625
# 26 2017-06-12  task-rest_acq-p2_bold.json  288.716065  0.055458
# 27 2017-06-19  task-rest_acq-p2_bold.json  253.758545  0.055389
# 28 2017-06-26  task-rest_acq-p2_bold.json  277.162415  0.000000
# 29 2017-07-03  task-rest_acq-p2_bold.json  219.683289  0.055401
# ..        ...                         ...         ...       ...
# 60 2018-02-19  task-rest_acq-p2_bold.json  260.691345  0.055577
# 61 2018-02-26  task-rest_acq-p2_bold.json  250.791382  0.055751
# 62 2018-03-05  task-rest_acq-p2_bold.json  247.038986  0.055660
# 63 2018-03-12  task-rest_acq-p2_bold.json  216.638168  0.055723
# 64 2018-03-19  task-rest_acq-p2_bold.json  149.788757  0.055807
# 65 2018-03-26  task-rest_acq-p2_bold.json  249.187500  0.055666
# 66 2018-04-05  task-rest_acq-p2_bold.json  230.266632  0.055685
# 67 2018-04-09  task-rest_acq-p2_bold.json  256.477356  0.055696
# 68 2018-04-16  task-rest_acq-p2_bold.json  219.759308  0.055850
# 69 2018-04-23  task-rest_acq-p2_bold.json  153.272156  0.055586
# 70 2018-04-26  task-rest_acq-p2_bold.json  270.747437  0.047640
# 71 2018-04-30  task-rest_acq-p2_bold.json  261.398315  0.055577
# 72 2018-05-07  task-rest_acq-p2_bold.json  246.563446  0.055581
# 73 2018-05-14  task-rest_acq-p2_bold.json  251.504349  0.055481
# 74 2018-05-29  task-rest_acq-p2_bold.json  170.289307  0.047706
# 75 2018-05-31  task-rest_acq-p2_bold.json  260.362152  0.055487
# 76 2018-06-04  task-rest_acq-p2_bold.json  247.724991  0.055310
# 77 2018-06-11  task-rest_acq-p2_bold.json  258.916473  0.055470
# 78 2018-06-18  task-rest_acq-p2_bold.json  222.139175  0.055556
# 80            38490   235.951     syngo_MR_E11
# 81            35378   234.563     syngo_MR_E11
# 82            32157   234.672     syngo_MR_E11
# 83            47315   236.183     syngo_MR_E11
# 84            45277   235.417     syngo_MR_E11
# 85            33644   235.016     syngo_MR_E11
# 86            45339   235.455     syngo_MR_E11
# 87            40692   238.067     syngo_MR_E11
# 88            34908   233.861     syngo_MR_E11
# 89            44486   234.145     syngo_MR_E11
#
#                                         CSV  RepetitionTime  Shim1  ...  \
# 0   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 1   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4149  ...
# 2   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 3   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4149  ...
# 4   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 5   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4153  ...
# 6   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 7   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 8   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4153  ...
# 9   v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4149  ...
# 10  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4160  ...
# 11  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4150  ...
# 12  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4169  ...
# 13  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4148  ...
# 14  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4157  ...
# 15  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4156  ...
# 16  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 17  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4145  ...
# 18  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4151  ...
# 19  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 20  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 21  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4151  ...
# 22  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4145  ...
# 23  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4137  ...
# 24  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4158  ...
# 25  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 26  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 27  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4142  ...
# 28  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4158  ...
# 29  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4163  ...
# ..                                      ...             ...    ...  ...
# 60  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 61  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4148  ...
# 62  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4143  ...
# 63  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 64  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 65  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4151  ...
# 66  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4148  ...
# 67  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 68  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 69  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4150  ...
# 70  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 71  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4145  ...
# 72  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 73  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4145  ...
# 74  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 75  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 76  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 77  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4143  ...
# 78  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4152  ...
# 79  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4148  ...
# 80  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4146  ...
# 81  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 82  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
# 83  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 84  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4141  ...
# 85  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 86  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4147  ...
# 87  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4139  ...
# 88  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4143  ...
# 89  v1.0.20171215 (OpenJPEG build) GCC6.3.0               2   4144  ...
#
#     Shim5  Shim6  Shim7  Shim8     IOPD1     IOPD2     IOPD3     IOPD4  \
# 0    -100    -97    -33     98  0.985878 -0.167457  0.001717  0.159148
# 1       9   -242    -24     30  0.971245  0.237250  0.019884 -0.232279
# 2     -25   -260    -53     97  0.998778  0.010514 -0.048293  0.003312
# 3     -99   -119    -42     98  0.986042 -0.166495  0.000148  0.158821
# 4     -12    243   -156    102  0.979289 -0.202465  0.000288  0.192484
# 5     -35   -103    -53     23  0.976428  0.215207  0.016569 -0.209863
# 6    -103    -87      0     77  0.975473 -0.220120 -0.000566  0.210548
# 7    -121   -209    -55    105  0.976117 -0.217242 -0.000866  0.207124
# 8     -81    -69    -21     90  0.992399 -0.123063  0.000294  0.117107
# 9     -97   -154    -20    104  0.985952 -0.167028 -0.000063  0.159336
# 10    -28   -226      3    111  0.981075  0.193157  0.013519 -0.187860
# 11    -59    -85    -31     74  0.986837  0.161515  0.008056 -0.156300
# 12    -42   -147    -50     71  0.973447 -0.228912 -0.000911  0.218305
# 13    -88   -212    -62     75  0.992260  0.124047  0.005723 -0.119550
# 14     12   -308    -29    103  0.979269  0.201993  0.015209 -0.196922
# 15     36   -148    -15    100  0.971916  0.234746  0.016549 -0.228677
# 16    -64   -131     14     56  0.999127  0.006165 -0.041321  0.006278
# 17    -55   -192    -61     55  0.999345  0.007244 -0.035442  0.002965
#
#        IOPD5     IOPD6
# 0   0.940050  0.301624
# 1   0.925939  0.297799
# 2   0.960676  0.277653
# 3   0.940861  0.299260
# 4   0.931450  0.308788
# 5   0.928625  0.305964
# 6   0.932299  0.294090
# 7   0.929438  0.305359
# 8   0.945097  0.305087
# 9   0.940434  0.300327
# 10  0.932601  0.308163
# 11  0.939820  0.303824
# 12  0.927126  0.304598
# 13  0.941785  0.314244
# 14  0.931704  0.305205
# 15  0.925504  0.301910
# 16  0.955667  0.294382
# 17  0.960043  0.279838
# 18  0.925401  0.301072
# 19  0.932874  0.300811
# 20  0.938767  0.301205
# 21  0.874841  0.467466
# 22  0.935565  0.298156
# 23  0.927542  0.333178
# 24  0.940219  0.306287
# 25  0.929848  0.303665
# 26  0.939045  0.304873
# 27  0.922471  0.349654
# 28  0.936318  0.296977
# 29  0.933812  0.304357
# ..       ...       ...
# 60  0.937918  0.307259
# 61  0.931266  0.304028
# 62  0.937111  0.298919
# 63  0.938546  0.301214
# 64  0.938691  0.299664
# 65  0.935119  0.295714
# 66  0.953236  0.302052
# 67  0.931222  0.362256
# 68  0.937947  0.303718
# 69  0.934825  0.301994
# 70  0.936980  0.306625
# 71  0.936127  0.308381
# 72  0.947816  0.302460
# 73  0.941533  0.302727
# 74  0.928380  0.303210
# 75  0.943145  0.292861
# 76  0.950034  0.304497
# 77  0.941919  0.301784
# 78  0.943873  0.272786
# 79  0.939289  0.305332
# 80  0.945955  0.302686
# 81  0.939736  0.303322
# 82  0.934308  0.309689
# 83  0.936716  0.312925
# 84  0.936622  0.307269
# 85  0.935227  0.305161
# 86  0.929548  0.305633
# 87  0.929485  0.303463
# 88  0.931091  0.341060
# 89  0.929504  0.305985
#
# [90 rows x 23 columns]

# %%
regress('tsnr', df)
# Out:
# /Users/chrischeng/nuisance/ipy/nuisancelib.py:146: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   model_array = orthogonalize(orthogonalized_df.as_matrix())
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return getattr(obj, method)(*args, **kwds)
# No Shim variables in the model
# IOPD F-test: <F test: F=array([[4.16607816]]), p=0.0011177782522775659, df_denom=77, df_num=6>
# Seasonal F-test: <F test: F=array([[2.64258901]]), p=0.07762664483847577, df_denom=77, df_num=2>
# Statistically significant variables: ['IOPD1', 'IOPD2', 'IOPD3', 'IOPD4', 'IOPD5', 'IOPD6', 'const', 'Seasonal (cos)']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   tsnr   R-squared:                       0.311
# Model:                            OLS   Adj. R-squared:                  0.204
# Method:                 Least Squares   F-statistic:                     2.900
# Date:                Fri, 03 Apr 2020   Prob (F-statistic):            0.00235
# Time:                        14:25:01   Log-Likelihood:                -418.39
# No. Observations:                  90   AIC:                             862.8
# Df Residuals:                      77   BIC:                             895.3
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             240.5757      2.881     83.518      0.000     234.840     246.312
# AcquisitionTime    -0.0004      0.001     -0.716      0.476      -0.002       0.001
# RepetitionTime   1853.1769   5744.215      0.323      0.748   -9585.015    1.33e+04
# SAR              -469.6393    449.083     -1.046      0.299   -1363.878     424.599
# TxRefAmp           -1.0669      0.637     -1.674      0.098      -2.336       0.202
# IOPD1            1245.1734    406.129      3.066      0.003     436.468    2053.879
# IOPD2              73.0289     18.764      3.892      0.000      35.665     110.393
# IOPD3              52.5221    299.552      0.175      0.861    -543.962     649.006
# IOPD4            -997.1781   5103.248     -0.195      0.846   -1.12e+04    9164.686
# IOPD5            -263.9669    527.569     -0.500      0.618   -1314.492     786.558
# IOPD6            -470.4457   1306.839     -0.360      0.720   -3072.694    2131.803
# Seasonal (sin)     -4.3643      4.453     -0.980      0.330     -13.230       4.502
# Seasonal (cos)     -9.5379      4.587     -2.080      0.041     -18.671      -0.405
# ==============================================================================
# Omnibus:                       24.814   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.213
# Skew:                          -1.264   Prob(JB):                     2.26e-08
# Kurtosis:                       4.733   Cond. No.                     9.65e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.65e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AIC: 862.7866503601534
# BIC: 895.2841760744469

# %%
# p2Xs4X35mm_BOLD.csv
df2 = pd.read_csv('../data/extractions/p2Xs4X35mm_BOLD.csv', parse_dates=['Date'])
df2
# Out:
#          Date                            Filetype        tsnr       SAR  \
# 0  2016-11-28  task-rest_acq-p2Xs4X35mm_bold.json  230.103912  0.077002
# 1  2016-12-05  task-rest_acq-p2Xs4X35mm_bold.json  226.028854  0.065921
# 2  2016-12-12  task-rest_acq-p2Xs4X35mm_bold.json  228.845230  0.066209
# 3  2016-12-19  task-rest_acq-p2Xs4X35mm_bold.json  207.193359  0.077200
# 4  2017-01-03  task-rest_acq-p2Xs4X35mm_bold.json  172.502716  0.077096
# 5  2017-01-09  task-rest_acq-p2Xs4X35mm_bold.json  223.143097  0.077234
# 6  2017-01-17  task-rest_acq-p2Xs4X35mm_bold.json  243.786545  0.077350
# 7  2017-01-23  task-rest_acq-p2Xs4X35mm_bold.json  199.646423  0.077266
# 8  2017-01-30  task-rest_acq-p2Xs4X35mm_bold.json  244.466827  0.077177
# 9  2017-02-06  task-rest_acq-p2Xs4X35mm_bold.json  254.696137  0.021036
# 10 2017-02-13  task-rest_acq-p2Xs4X35mm_bold.json  299.460571  0.017956
# 11 2017-02-27  task-rest_acq-p2Xs4X35mm_bold.json  296.864502  0.020951
# 12 2017-03-09  task-rest_acq-p2Xs4X35mm_bold.json  235.320526  0.017950
# 13 2017-03-13  task-rest_acq-p2Xs4X35mm_bold.json  239.435944  0.017942
# 14 2017-03-20  task-rest_acq-p2Xs4X35mm_bold.json  236.621750  0.020920
# 15 2017-03-27  task-rest_acq-p2Xs4X35mm_bold.json  232.087540  0.020929
# 16 2017-03-29  task-rest_acq-p2Xs4X35mm_bold.json  302.373993  0.020987
# 17 2017-04-03  task-rest_acq-p2Xs4X35mm_bold.json  279.123016  0.020947
# 18 2017-04-10  task-rest_acq-p2Xs4X35mm_bold.json  272.198792  0.020865
# 19 2017-04-17  task-rest_acq-p2Xs4X35mm_bold.json  282.812775  0.020920
# 20 2017-04-24  task-rest_acq-p2Xs4X35mm_bold.json  243.746033  0.017894
# 21 2017-05-01  task-rest_acq-p2Xs4X35mm_bold.json  288.941223  0.020931
# 22 2017-05-08  task-rest_acq-p2Xs4X35mm_bold.json  264.793762  0.017998
# 23 2017-05-15  task-rest_acq-p2Xs4X35mm_bold.json  281.640381  0.020951
# 24 2017-05-22  task-rest_acq-p2Xs4X35mm_bold.json  279.601837  0.020943
# 25 2017-05-30  task-rest_acq-p2Xs4X35mm_bold.json  263.224304  0.020916
# 26 2017-06-12  task-rest_acq-p2Xs4X35mm_bold.json  291.626343  0.020854
# 27 2017-06-19  task-rest_acq-p2Xs4X35mm_bold.json  291.835113  0.020828
# 28 2017-06-26  task-rest_acq-p2Xs4X35mm_bold.json  288.613129  0.000000
# 29 2017-07-03  task-rest_acq-p2Xs4X35mm_bold.json  248.258728  0.020833
# ..        ...                                 ...         ...       ...
# 60 2018-02-19  task-rest_acq-p2Xs4X35mm_bold.json  253.287384  0.020899
# 61 2018-02-26  task-rest_acq-p2Xs4X35mm_bold.json  261.242859  0.020964
# 62 2018-03-05  task-rest_acq-p2Xs4X35mm_bold.json  271.689392  0.020930
# 63 2018-03-12  task-rest_acq-p2Xs4X35mm_bold.json  235.443527  0.020953
# 64 2018-03-19  task-rest_acq-p2Xs4X35mm_bold.json  193.129120  0.020985
# 65 2018-03-26  task-rest_acq-p2Xs4X35mm_bold.json  282.559967  0.020932
# 66 2018-04-05  task-rest_acq-p2Xs4X35mm_bold.json  246.247238  0.020939
# 67 2018-04-09  task-rest_acq-p2Xs4X35mm_bold.json  274.633637  0.020944
# 68 2018-04-16  task-rest_acq-p2Xs4X35mm_bold.json  241.575897  0.021001
# 69 2018-04-23  task-rest_acq-p2Xs4X35mm_bold.json  212.193420  0.020902
# 70 2018-04-26  task-rest_acq-p2Xs4X35mm_bold.json  280.008758  0.017914
# 71 2018-04-30  task-rest_acq-p2Xs4X35mm_bold.json  253.901733  0.020899
# 72 2018-05-07  task-rest_acq-p2Xs4X35mm_bold.json  272.097290  0.020900
# 73 2018-05-14  task-rest_acq-p2Xs4X35mm_bold.json  249.792725  0.020862
# 74 2018-05-29  task-rest_acq-p2Xs4X35mm_bold.json  212.710190  0.017939
# 75 2018-05-31  task-rest_acq-p2Xs4X35mm_bold.json  262.068970  0.020865
# 76 2018-06-04  task-rest_acq-p2Xs4X35mm_bold.json  261.306213  0.020798
# 77 2018-06-11  task-rest_acq-p2Xs4X35mm_bold.json  254.617248  0.020858
# 78 2018-06-18  task-rest_acq-p2Xs4X35mm_bold.json  242.962845  0.020891
# 79 2018-06-25  task-rest_acq-p2Xs4X35mm_bold.json  236.210754  0.020829
# 80 2018-07-02  task-rest_acq-p2Xs4X35mm_bold.json  267.851013  0.020957
# 81 2018-07-09  task-rest_acq-p2Xs4X35mm_bold.json  250.284134  0.020871
# 82 2018-07-23  task-rest_acq-p2Xs4X35mm_bold.json  276.698059  0.020895
# 83 2018-07-30  task-rest_acq-p2Xs4X35mm_bold.json  227.207550  0.020830
# 84 2018-08-09  task-rest_acq-p2Xs4X35mm_bold.json  273.850891  0.020897
# 85 2018-08-13  task-rest_acq-p2Xs4X35mm_bold.json  251.972931  0.020844
v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4144  ...
# 1   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4149  ...
# 2   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4146  ...
# 3   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4148  ...
# 4   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4144  ...
# 5   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4153  ...
# 6   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4143  ...
# 7   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4146  ...
# 8   v1.0.20171215 (OpenJPEG build) GCC6.3.0           0.525   4153  ...
# 9   v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4149  ...
# 10  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4160  ...
# 11  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4150  ...
# 12  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4169  ...
# 13  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4148  ...
# 14  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4157  ...
# 15  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4156  ...
# 16  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 17  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
# 18  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4151  ...
# 19  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 20  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 21  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4151  ...
# 22  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
# 23  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4137  ...
# 24  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4158  ...
# 25  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 26  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 27  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4142  ...
# 28  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4158  ...
# 29  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4164  ...
# ..                                      ...             ...    ...  ...
# 60  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 61  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4148  ...
# 62  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 63  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 64  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
# 65  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4152  ...
# 66  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4148  ...
# 67  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 68  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 69  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4150  ...
# 70  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 71  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
# 72  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 73  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
# 74  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 75  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 76  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 77  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4143  ...
# 78  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4152  ...
# 79  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4148  ...
# 80  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 81  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4146  ...
# 82  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4144  ...
# 83  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 84  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4141  ...
# 85  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 86  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4147  ...
# 87  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4139  ...
# 88  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4143  ...
# 89  v1.0.20171215 (OpenJPEG build) GCC6.3.0           2.000   4145  ...
#
#     Shim5  Shim6  Shim7  Shim8     IOPD1     IOPD2     IOPD3     IOPD4  \
# 0    -100    -96    -31     96  0.985878 -0.167457  0.001717  0.159148
# 1       6   -249    -25     29  0.971245  0.237250  0.019884 -0.232279
# 2     -24   -256    -50     96  0.998778  0.010514 -0.048293  0.003312
# 3     -96   -122    -42     96  0.986042 -0.166495  0.000148  0.158821
# 4      -7    254   -150    100  0.979289 -0.202465  0.000288  0.192484
# 5     -34   -106    -52     23  0.976428  0.215207  0.016569 -0.209863
# 6    -103    -86      1     77  0.975473 -0.220120 -0.000566  0.210548
# 7    -117   -215    -53    103  0.976117 -0.217242 -0.000866  0.207124
# 8     -80    -68    -19     90  0.992399 -0.123063  0.000294  0.117107
# 9     -92   -158    -19    102  0.985952 -0.167028 -0.000063  0.159336
# 10    -25   -235      0    111  0.981075  0.193157  0.013519 -0.187860
# 11    -57    -83    -28     72  0.986837  0.161515  0.008056 -0.156300
# 12    -32   -144    -47     65  0.973447 -0.228912 -0.000911  0.218305
# 13    -89   -215    -59     74  0.992260  0.124047  0.005723 -0.119550
# 14     14   -313    -29    102  0.979269  0.201993  0.015209 -0.196922
# 15     39   -152    -14     98  0.971916  0.234746  0.016549 -0.228677
# 16    -65   -131     16     56  0.999127  0.006165 -0.041321  0.006278
# 17    -55   -194    -60     54  0.999345  0.007244 -0.035442  0.002965
# 18     43   -254    -53     84  0.971515  0.236432  0.016084 -0.230194
# 19    -40   -161    -22     34  0.979135  0.202505  0.016935 -0.198140
# 20    -11   -275    -89     81  0.985016  0.172131  0.010666 -0.167310
# 21    -65   -150      9     81  0.991369 -0.127409 -0.030888  0.126997
# 8   0.945097  0.305087
# 9   0.940434  0.300327
# 10  0.932601  0.308163
# 11  0.939820  0.303824
# 12  0.927126  0.304598
# 13  0.941785  0.314244
# 14  0.931704  0.305205
# 15  0.925504  0.301910
# 16  0.955667  0.294382
# 17  0.960043  0.279838
# 18  0.925401  0.301072
# 19  0.932874  0.300811
# 20  0.938767  0.301205
# 21  0.874841  0.467466
# 22  0.935565  0.298156
# 23  0.927542  0.333178
# 24  0.940219  0.306287
# 25  0.929848  0.303665
# 26  0.939045  0.304873
# 27  0.922471  0.349654
# 28  0.936318  0.296977
# 29  0.933812  0.304357
# ..       ...       ...
# 60  0.937918  0.307259
# 61  0.931266  0.304028
# 62  0.937111  0.298919
# 63  0.938546  0.301214
# 64  0.938691  0.299664
# 65  0.935119  0.295714
# 66  0.953236  0.302052
# 67  0.931222  0.362256
# 68  0.937947  0.303718
# 69  0.934825  0.301994
# 70  0.936980  0.306625
# 71  0.936127  0.308381
# 72  0.947816  0.302460
# 73  0.941533  0.302727
# 74  0.928380  0.303210
# 75  0.943145  0.292861
# 76  0.950034  0.304497
# 77  0.941919  0.301784
# 78  0.943873  0.272786
# 79  0.939289  0.305332
# 80  0.945955  0.302686
# 81  0.939736  0.303322
# 82  0.934308  0.309689
# 83  0.936716  0.312925
# 84  0.936622  0.307269
# 85  0.935227  0.305161
# 86  0.929548  0.305633
# 87  0.929485  0.303463
# 88  0.931091  0.341060
# 89  0.929504  0.305985
#
# [90 rows x 23 columns]

# %%
regress('tsnr', df2)
# Out:
# /Users/chrischeng/nuisance/ipy/nuisancelib.py:146: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   model_array = orthogonalize(orthogonalized_df.as_matrix())
# /anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return getattr(obj, method)(*args, **kwds)
# No Shim variables in the model
# IOPD F-test: <F test: F=array([[1.83158019]]), p=0.10388000491924336, df_denom=77, df_num=6>
# Seasonal F-test: <F test: F=array([[2.15853356]]), p=0.1224326420732513, df_denom=77, df_num=2>
# Statistically significant variables: ['const', 'RepetitionTime', 'IOPD1']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   tsnr   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.286
# Method:                 Least Squares   F-statistic:                     3.969
# Date:                Wed, 08 Apr 2020   Prob (F-statistic):           9.19e-05
# Time:                        20:51:13   Log-Likelihood:                -400.30
# No. Observations:                  90   AIC:                             826.6
# Df Residuals:                      77   BIC:                             859.1
# Df Model:                          12
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             254.7211      2.356    108.120      0.000     250.030     259.412
# AcquisitionTime    -0.0005      0.000     -1.125      0.264      -0.002       0.000
# RepetitionTime     26.9318      5.334      5.049      0.000      16.310      37.554
# SAR             -1603.8971    838.328     -1.913      0.059   -3273.222      65.428
# TxRefAmp           -0.7252      0.525     -1.382      0.171      -1.770       0.320
# IOPD1             851.7336    332.821      2.559      0.012     189.002    1514.465
# IOPD2              19.3399     15.776      1.226      0.224     -12.073      50.753
# IOPD3            -190.3714    242.287     -0.786      0.434    -672.827     292.084
# IOPD4           -6198.4629   4193.206     -1.478      0.143   -1.45e+04    2151.278
# IOPD5            -101.0038    443.806     -0.228      0.821    -984.735     782.727
# IOPD6            -310.6128   1077.499     -0.288      0.774   -2456.188    1834.962
# Seasonal (sin)     -3.0531      3.652     -0.836      0.406     -10.326       4.220
# Seasonal (cos)     -7.5949      3.993     -1.902      0.061     -15.545       0.356
# ==============================================================================
# Omnibus:                        1.378   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.502   Jarque-Bera (JB):                1.429
# Skew:                          -0.241   Prob(JB):                        0.489
# Kurtosis:                       2.615   Cond. No.                     8.62e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.62e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AIC: 826.5977603732642
# BIC: 859.0952860875577

# %%
df3 = pd.read_csv('../data/extractions/anat.csv', parse_dates=['Date'])
df3
# Out:
#          Date  AcquisitionTime  RepetitionTime       SAR  TxRefAmp     IOPD1  \
# 0  2017-10-30            39009             2.3  0.033092   230.573  0.976457
# 1  2017-11-06            41814             2.3  0.033160   231.487 -0.008877
# 2  2017-11-13            37638             2.3  0.033247   231.326 -0.149058
# 3  2017-11-20            36473             2.3  0.033159   229.930 -0.148262
# 4  2017-11-27            37165             2.3  0.033078   227.070 -0.159926
# 5  2017-12-04            41697             2.3  0.033255   231.932 -0.007184
# 6  2017-12-18            35022             2.3  0.033263   227.181 -0.178403
# 7  2018-01-02            42512             2.3  0.033227   227.526 -0.005452
# 8  2018-01-08            34889             2.3  0.028424   231.071 -0.146475
# 9  2018-01-15            36327             2.3  0.039198   226.420  0.137367
# 10 2018-01-22            54287             2.3  0.033313   233.036 -0.150067
# 11 2018-01-29            37194             2.3  0.033188   235.564  0.156184
# 12 2018-02-05            37607             2.3  0.039186   231.349  0.138340
# 13 2018-02-12            33660             2.3  0.028386   230.705 -0.159486
# 14 2018-02-19            35612             2.3  0.033141   229.376 -0.160957
# 15 2018-02-26            33390             2.3  0.033244   232.820 -0.200869
# 16 2018-03-05            35167             2.3  0.033191   229.223 -0.180274
# 17 2018-03-12            34890             2.3  0.033228   232.269 -0.168463
# 18 2018-03-19            35903             2.3  0.033278   227.849  0.170401
# 19 2018-03-26            34980             2.3  0.033194   230.030 -0.195285
# 20 2018-04-05            37667             2.3  0.033205   231.664 -0.010319
# 21 2018-04-09            32961             2.3  0.033212   229.727  0.039958
# 22 2018-04-16            36349             2.3  0.033304   232.243  0.167408
# 23 2018-04-23            36273             2.3  0.033146   230.270 -0.186873
# 24 2018-04-26            34203             2.3  0.028408   231.226 -0.167562
# 25 2018-04-30            33076             2.3  0.033141   232.198 -0.169028
# 26 2018-05-07            38793             2.3  0.033143   233.584  0.100726
# 27 2018-05-14            33410             2.3  0.033083   237.643 -0.147892
# 28 2018-05-29            59495             2.3  0.028448   237.711 -0.214959
# 29 2018-05-31            32951             2.3  0.033087   235.255 -0.157266
# 30 2018-06-04            49427             2.3  0.032982   233.526  0.068743
# 31 2018-06-11            39481             2.3  0.033077   235.423 -0.147437
# 32 2018-06-18            36105             2.3  0.033129   236.930  0.186292
# 33 2018-06-25            41604             2.3  0.033031   234.779  0.156515
# 34 2018-07-02            39708             2.3  0.033234   235.951  0.116411
# 35 2018-07-09            36599             2.3  0.033097   234.563  0.157732
# 35  0.939728  0.303367  0.052389  0.298817 -0.952871  47.679879
# 36  0.934323  0.309672 -0.049688  0.305753 -0.950814  53.042607
# 37  0.936696  0.312988 -0.043516  0.310049 -0.949724  52.508069
# 38  0.936598  0.307349 -0.047176  0.303786 -0.951572  51.073192
# 39  0.935215  0.305196  0.059194  0.299405 -0.952288  48.412473
# 40  0.929543  0.305679 -0.055573  0.300763 -0.952078  51.739376
# 41  0.929463  0.303498 -0.050965  0.299587 -0.952707  46.076735
# 42  0.931101  0.341009  0.033693  0.339574 -0.939976  47.538107
# 43  0.929514  0.306007 -0.054270  0.301379 -0.951959  48.585167
#
#                Filetype SoftwareVersions  \
# 0   acq-MPRAGE_T1w.json     syngo_MR_E11
# 1   acq-MPRAGE_T1w.json     syngo_MR_E11
# 2   acq-MPRAGE_T1w.json     syngo_MR_E11
# 3   acq-MPRAGE_T1w.json     syngo_MR_E11
# 4   acq-MPRAGE_T1w.json     syngo_MR_E11
# 5   acq-MPRAGE_T1w.json     syngo_MR_E11
# 6   acq-MPRAGE_T1w.json     syngo_MR_E11
# 7   acq-MPRAGE_T1w.json     syngo_MR_E11
# 8   acq-MPRAGE_T1w.json     syngo_MR_E11
# 9   acq-MPRAGE_T1w.json     syngo_MR_E11
# 10  acq-MPRAGE_T1w.json     syngo_MR_E11
# 11  acq-MPRAGE_T1w.json     syngo_MR_E11
# 12  acq-MPRAGE_T1w.json     syngo_MR_E11
# 13  acq-MPRAGE_T1w.json     syngo_MR_E11
# 14  acq-MPRAGE_T1w.json     syngo_MR_E11
# 15  acq-MPRAGE_T1w.json     syngo_MR_E11
# 16  acq-MPRAGE_T1w.json     syngo_MR_E11
# 17  acq-MPRAGE_T1w.json     syngo_MR_E11
# 18  acq-MPRAGE_T1w.json     syngo_MR_E11
# 19  acq-MPRAGE_T1w.json     syngo_MR_E11
# 20  acq-MPRAGE_T1w.json     syngo_MR_E11
# 21  acq-MPRAGE_T1w.json     syngo_MR_E11
# 22  acq-MPRAGE_T1w.json     syngo_MR_E11
# 23  acq-MPRAGE_T1w.json     syngo_MR_E11
# 24  acq-MPRAGE_T1w.json     syngo_MR_E11
# 25  acq-MPRAGE_T1w.json     syngo_MR_E11
# 26  acq-MPRAGE_T1w.json     syngo_MR_E11
# 27  acq-MPRAGE_T1w.json     syngo_MR_E11
# 28  acq-MPRAGE_T1w.json     syngo_MR_E11
# 29  acq-MPRAGE_T1w.json     syngo_MR_E11
# 30  acq-MPRAGE_T1w.json     syngo_MR_E11
# 31  acq-MPRAGE_T1w.json     syngo_MR_E11
# 32  acq-MPRAGE_T1w.json     syngo_MR_E11
# 33  acq-MPRAGE_T1w.json     syngo_MR_E11
# 34  acq-MPRAGE_T1w.json     syngo_MR_E11
# 35  acq-MPRAGE_T1w.json     syngo_MR_E11
# 36  acq-MPRAGE_T1w.json     syngo_MR_E11
# 37  acq-MPRAGE_T1w.json     syngo_MR_E11
# 38  acq-MPRAGE_T1w.json     syngo_MR_E11
# 39  acq-MPRAGE_T1w.json     syngo_MR_E11
# 40  acq-MPRAGE_T1w.json     syngo_MR_E11
# 41  acq-MPRAGE_T1w.json     syngo_MR_E11
# 42  acq-MPRAGE_T1w.json     syngo_MR_E11
# 43  acq-MPRAGE_T1w.json     syngo_MR_E11
#
#                                         CSV
# 0   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 1   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 2   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 3   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 4   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 5   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 6   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 7   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 8   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 9   v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 10  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 11  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 12  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 13  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 14  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 15  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 16  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 17  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 18  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 19  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 20  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 21  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 22  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 23  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 24  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 25  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 26  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 27  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 28  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 29  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 30  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 31  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 32  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 33  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 34  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 35  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 36  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 37  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 38  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 39  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 40  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 41  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 42  v1.0.20171215 (OpenJPEG build) GCC6.3.0
# 43  v1.0.20171215 (OpenJPEG build) GCC6.3.0

# %%
regress('snr_total', df3)
# Out:
# /Users/chrischeng/nuisance/ipy/nuisancelib.py:131: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   model_df['Date'] = model_df['Date'].map(pd.datetime.toordinal)
# Statistically significant variables: ['IOPD1', 'IOPD2', 'IOPD3', 'IOPD4', 'IOPD5', 'IOPD6', 'const', 'AcquisitionTime', 'SAR']
# FDR-corrected p-values:
# AcquisitionTime | Original p-value: 0.018760498268839607 | FDR-corrected p-value: 0.03126749711473268, True
#             SAR | Original p-value:  0.00349385101477872 | FDR-corrected p-value: 0.0174692550738936, True
#        TxRefAmp | Original p-value:   0.3815907729452217 | FDR-corrected p-value: 0.4769884661815271, False
#            IOPD | Original p-value: 0.015274677773496646 | FDR-corrected p-value: 0.03126749711473268, True
#        Seasonal | Original p-value:   0.6686032924004516 | FDR-corrected p-value: 0.6686032924004516, False
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              snr_total   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.373
# Method:                 Least Squares   F-statistic:                     3.326
# Date:                Thu, 04 Jun 2020   Prob (F-statistic):            0.00385
# Time:                        20:42:44   Log-Likelihood:                -87.912
# No. Observations:                  44   AIC:                             199.8
# Df Residuals:                      32   BIC:                             221.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              49.9188      0.315    158.253      0.000      49.276      50.561
# AcquisitionTime     0.0001   5.35e-05      2.476      0.019    2.35e-05       0.000
# SAR               492.2450    156.081      3.154      0.003     174.319     810.171
# TxRefAmp           -0.1033      0.116     -0.887      0.382      -0.340       0.134
# IOPD1              -2.8141      1.572     -1.790      0.083      -6.016       0.388
# IOPD2               7.5256      4.485      1.678      0.103      -1.610      16.661
# IOPD3             -67.4875     22.938     -2.942      0.006    -114.210     -20.765
# IOPD4              -8.3575     40.955     -0.204      0.840     -91.780      75.065
# IOPD5              93.1890     46.409      2.008      0.053      -1.342     187.720
# IOPD6             114.7569    289.843      0.396      0.695    -475.634     705.148
# Seasonal (sin)     -0.2147      0.546     -0.393      0.697      -1.326       0.897
# Seasonal (cos)      0.6067      0.746      0.813      0.422      -0.914       2.127
# ==============================================================================
# Omnibus:                        0.926   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.463
# Skew:                           0.245   Prob(JB):                        0.793
# Kurtosis:                       3.114   Cond. No.                     5.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# AIC: 199.82491179026405
# BIC: 221.2351873972832
